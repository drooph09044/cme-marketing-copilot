# %%
# %sh 
cd /Workspace/Users/mandala330323@exlservice.com/cme-marketing-copilot/Source-Code

NODE_VERSION=v20.15.1
NODE_BASE=/tmp/codex-node
NODE_DIR=$NODE_BASE/node-$NODE_VERSION-linux-x64

mkdir -p "$NODE_BASE"

if [ ! -x "$NODE_DIR/bin/npm" ]; then
  curl -L "https://nodejs.org/dist/$NODE_VERSION/node-$NODE_VERSION-linux-x64.tar.xz" -o "$NODE_BASE/node.tar.xz"
  tar -xJf "$NODE_BASE/node.tar.xz" -C "$NODE_BASE"
fi

"$NODE_DIR/bin/node" -v
"$NODE_DIR/bin/npm" -v

"$NODE_DIR/bin/npm" install
"$NODE_DIR/bin/npm" run build

# %%
Get-ChildItem -Recurse -File |
Sort-Object Length -Descending |
Select-Object -First 30 FullName,
@{Name="SizeMB";Expression={:Round($_.Length/1MB,2)}}

# %%
git rm -r --cached Source-Code\venv
git rm -r --cached Source-Code\.tools
git rm -r --cached Source-Code\legacy_idres
git rm -r --cached Source-Code\qa-automation-beta-v3\apps\web\.next

# %%
# !find /Workspace/Users/mandala330323@exlservice.com -type d -name Source-Code

# %%
# %sh
which node
node -v
which npm
npm -v

# %%
# %sh
find /usr -name npm 2>/dev/null | head -20

# %%
# %sh
ls -l /usr/local/bin/npm

# %%
# %sh
sudo apt-get update

# %%
cd qa-automation-beta-v3/apps/web

# %%
# %sh
find /Workspace -name "package.json" 2>/dev/null
